# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
# Generate sample time series data
np.random.seed(42)
date_range = pd.date_range(start='2022-01-01', end='2022-12-31', freq='D')
data = pd.DataFrame({
    'Date': date_range,
    'Value': np.random.randn(len(date_range))
})
data.set_index('Date', inplace=True)
data
# Out:
#                Value
# Date
# 2022-01-01  0.496714
# 2022-01-02 -0.138264
# 2022-01-03  0.647689
# 2022-01-04  1.523030
# 2022-01-05 -0.234153
# ...              ...
# 2022-12-27  0.519347
# 2022-12-28  1.532739
# 2022-12-29 -0.108760
# 2022-12-30  0.401712
# 2022-12-31  0.690144
#
# [365 rows x 1 columns]

# %%
# 1. Lag Features
for lag in range(1, 8):
    data[f'lag_{lag}'] = data['Value'].shift(lag)
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7
# Date
# 2022-01-01       NaN       NaN
# 2022-01-02       NaN       NaN
# 2022-01-03       NaN       NaN
# 2022-01-04       NaN       NaN
# 2022-01-05       NaN       NaN
# ...              ...       ...
# 2022-12-27 -0.019016 -0.159939
# 2022-12-28 -1.002529 -0.019016
# 2022-12-29 -0.018513 -1.002529
# 2022-12-30 -0.288659 -0.018513
# 2022-12-31  0.322719 -0.288659
#
# [365 rows x 8 columns]

# %%
# 2. Rolling Window Statistics
data['rolling_mean'] = data['Value'].rolling(window=7).mean()
data['rolling_std'] = data['Value'].rolling(window=7).std()
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7  rolling_mean  rolling_std
# Date
# 2022-01-01       NaN       NaN           NaN          NaN
# 2022-01-02       NaN       NaN           NaN          NaN
# 2022-01-03       NaN       NaN           NaN          NaN
# 2022-01-04       NaN       NaN           NaN          NaN
# 2022-01-05       NaN       NaN           NaN          NaN
# ...              ...       ...           ...          ...
# 2022-12-27 -0.019016 -0.159939     -0.187698     0.562829
# 2022-12-28 -1.002529 -0.019016      0.033982     0.864881
# 2022-12-29 -0.018513 -1.002529      0.161663     0.743866
# 2022-12-30 -0.288659 -0.018513      0.221695     0.743858
# 2022-12-31  0.322719 -0.288659      0.361524     0.723656
#
# [365 rows x 10 columns]

# %%
# 3. Expanding Window Statistics
data['expanding_mean'] = data['Value'].expanding().mean()
data['expanding_std'] = data['Value'].expanding().std()
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7  rolling_mean  rolling_std  expanding_mean  \
# Date
# 2022-01-01       NaN       NaN           NaN          NaN        0.496714
# 2022-01-02       NaN       NaN           NaN          NaN        0.179225
# 2022-01-03       NaN       NaN           NaN          NaN        0.335379
# 2022-01-04       NaN       NaN           NaN          NaN        0.632292
# 2022-01-05       NaN       NaN           NaN          NaN        0.459003
# ...              ...       ...           ...          ...             ...
# 2022-12-27 -0.019016 -0.159939     -0.187698     0.562829        0.003088
# 2022-12-28 -1.002529 -0.019016      0.033982     0.864881        0.007313
# 2022-12-29 -0.018513 -1.002529      0.161663     0.743866        0.006993
# 2022-12-30 -0.288659 -0.018513      0.221695     0.743858        0.008078
# 2022-12-31  0.322719 -0.288659      0.361524     0.723656        0.009946
#
#             expanding_std
# Date
# 2022-01-01            NaN
# 2022-01-02       0.448998
# 2022-01-03       0.417076
# 2022-01-04       0.684541
# 2022-01-05       0.708232
# ...                   ...
# 2022-12-27       0.948972
# 2022-12-28       0.951061
# 2022-12-29       0.949766
# 2022-12-30       0.948683
# 2022-12-31       0.948051
#
# [365 rows x 12 columns]

# %%
# 4. Datetime Features
data['day_of_week'] = data.index.dayofweek
data['month'] = data.index.month
data['quarter'] = data.index.quarter
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7  rolling_mean  rolling_std  expanding_mean  \
# Date
# 2022-01-01       NaN       NaN           NaN          NaN        0.496714
# 2022-01-02       NaN       NaN           NaN          NaN        0.179225
# 2022-01-03       NaN       NaN           NaN          NaN        0.335379
# 2022-01-04       NaN       NaN           NaN          NaN        0.632292
# 2022-01-05       NaN       NaN           NaN          NaN        0.459003
# ...              ...       ...           ...          ...             ...
# 2022-12-27 -0.019016 -0.159939     -0.187698     0.562829        0.003088
# 2022-12-28 -1.002529 -0.019016      0.033982     0.864881        0.007313
# 2022-12-29 -0.018513 -1.002529      0.161663     0.743866        0.006993
# 2022-12-30 -0.288659 -0.018513      0.221695     0.743858        0.008078
# 2022-12-31  0.322719 -0.288659      0.361524     0.723656        0.009946
#
#             expanding_std  day_of_week  month  quarter
# Date
# 2022-01-01            NaN            5      1        1
# 2022-01-02       0.448998            6      1        1
# 2022-01-03       0.417076            0      1        1
# 2022-01-04       0.684541            1      1        1
# 2022-01-05       0.708232            2      1        1
# ...                   ...          ...    ...      ...
# 2022-12-27       0.948972            1     12        4
# 2022-12-28       0.951061            2     12        4
# 2022-12-29       0.949766            3     12        4
# 2022-12-30       0.948683            4     12        4
# 2022-12-31       0.948051            5     12        4
#
# [365 rows x 15 columns]

# %%
# 5. Seasonal Features (Example: Fourier Transformation)
fourier_terms = 5  # Number of Fourier terms
for i in range(1, fourier_terms + 1):
    data[f'fourier_{i}'] = np.sin(2 * np.pi * i * data.index.dayofyear / 365.25)
    data[f'fourier_{i}'] = StandardScaler().fit_transform(data[[f'fourier_{i}']])
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7  rolling_mean  rolling_std  expanding_mean  \
# Date
# 2022-01-01       NaN       NaN           NaN          NaN        0.496714
# 2022-01-02       NaN       NaN           NaN          NaN        0.179225
# 2022-01-03       NaN       NaN           NaN          NaN        0.335379
# 2022-01-04       NaN       NaN           NaN          NaN        0.632292
# 2022-01-05       NaN       NaN           NaN          NaN        0.459003
# ...              ...       ...           ...          ...             ...
# 2022-12-27 -0.019016 -0.159939     -0.187698     0.562829        0.003088
# 2022-12-28 -1.002529 -0.019016      0.033982     0.864881        0.007313
# 2022-12-29 -0.018513 -1.002529      0.161663     0.743866        0.006993
# 2022-12-30 -0.288659 -0.018513      0.221695     0.743858        0.008078
# 2022-12-31  0.322719 -0.288659      0.361524     0.723656        0.009946
#
#             expanding_std  day_of_week  month  quarter  fourier_1  fourier_2  \
# Date
# 2022-01-01            NaN            5      1        1   0.024325   0.048642
# 2022-01-02       0.448998            6      1        1   0.048636   0.097214
# 2022-01-03       0.417076            0      1        1   0.072933   0.145671
# 2022-01-04       0.684541            1      1        1   0.097208   0.193956
# 2022-01-05       0.708232            2      1        1   0.121454   0.242011
# ...                   ...          ...    ...      ...        ...        ...
# 2022-12-27       0.948972            1     12        4  -0.103260  -0.205968
# 2022-12-28       0.951061            2     12        4  -0.078991  -0.157736
# 2022-12-29       0.949766            3     12        4  -0.054699  -0.109316
# 2022-12-30       0.948683            4     12        4  -0.030391  -0.060768
# 2022-12-31       0.948051            5     12        4  -0.006074  -0.012147
#
#             fourier_3  fourier_4  fourier_5
# Date
# 2022-01-01   0.072945   0.097227   0.121479
# 2022-01-02   0.145677   0.193968   0.242029
# 2022-01-03   0.218022   0.289792   0.360790
# 2022-01-04   0.289785   0.384244   0.476884
# 2022-01-05   0.360778   0.476878   0.589452
# ...               ...        ...        ...
# 2022-12-27  -0.307576  -0.407540  -0.505327
# 2022-12-28  -0.235987  -0.313501  -0.390035
# 2022-12-29  -0.163770  -0.217978  -0.271859
# 2022-12-30  -0.091116  -0.121423  -0.151673
# 2022-12-31  -0.018220  -0.024293  -0.030366
#
# [365 rows x 20 columns]

# %%
# 6. Time-based Features
data['days_since_start'] = (data.index - data.index[0]).days
data['days_until_end_of_year'] = (data.index.max() - data.index).days
data
# Out:
#                Value     lag_1     lag_2     lag_3     lag_4     lag_5  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN       NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN       NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN       NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN       NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714       NaN
# ...              ...       ...       ...       ...       ...       ...
# 2022-12-27  0.519347 -0.827231  0.322719 -0.288659 -0.018513 -1.002529
# 2022-12-28  1.532739  0.519347 -0.827231  0.322719 -0.288659 -0.018513
# 2022-12-29 -0.108760  1.532739  0.519347 -0.827231  0.322719 -0.288659
# 2022-12-30  0.401712 -0.108760  1.532739  0.519347 -0.827231  0.322719
# 2022-12-31  0.690144  0.401712 -0.108760  1.532739  0.519347 -0.827231
#
#                lag_6     lag_7  rolling_mean  rolling_std  ...  day_of_week  \
# Date                                                       ...
# 2022-01-01       NaN       NaN           NaN          NaN  ...            5
# 2022-01-02       NaN       NaN           NaN          NaN  ...            6
# 2022-01-03       NaN       NaN           NaN          NaN  ...            0
# 2022-01-04       NaN       NaN           NaN          NaN  ...            1
# 2022-01-05       NaN       NaN           NaN          NaN  ...            2
# ...              ...       ...           ...          ...  ...          ...
# 2022-12-27 -0.019016 -0.159939     -0.187698     0.562829  ...            1
# 2022-12-28 -1.002529 -0.019016      0.033982     0.864881  ...            2
# 2022-12-29 -0.018513 -1.002529      0.161663     0.743866  ...            3
# 2022-12-30 -0.288659 -0.018513      0.221695     0.743858  ...            4
# 2022-12-31  0.322719 -0.288659      0.361524     0.723656  ...            5
#
#             month  quarter  fourier_1  fourier_2  fourier_3  fourier_4  \
# Date
# 2022-01-01      1        1   0.024325   0.048642   0.072945   0.097227
# 2022-01-02      1        1   0.048636   0.097214   0.145677   0.193968
# 2022-01-03      1        1   0.072933   0.145671   0.218022   0.289792
# 2022-01-04      1        1   0.097208   0.193956   0.289785   0.384244
# 2022-01-05      1        1   0.121454   0.242011   0.360778   0.476878
# ...           ...      ...        ...        ...        ...        ...
# 2022-12-27     12        4  -0.103260  -0.205968  -0.307576  -0.407540
# 2022-12-28     12        4  -0.078991  -0.157736  -0.235987  -0.313501
# 2022-12-29     12        4  -0.054699  -0.109316  -0.163770  -0.217978
# 2022-12-30     12        4  -0.030391  -0.060768  -0.091116  -0.121423
# 2022-12-31     12        4  -0.006074  -0.012147  -0.018220  -0.024293
#
#             fourier_5  days_since_start  days_until_end_of_year
# Date
# 2022-01-01   0.121479                 0                     364
# 2022-01-02   0.242029                 1                     363
# 2022-01-03   0.360790                 2                     362
# 2022-01-04   0.476884                 3                     361
# 2022-01-05   0.589452                 4                     360
# ...               ...               ...                     ...
# 2022-12-27  -0.505327               360                       4
# 2022-12-28  -0.390035               361                       3
# 2022-12-29  -0.271859               362                       2
# 2022-12-30  -0.151673               363                       1
# 2022-12-31  -0.030366               364                       0
#
# [365 rows x 22 columns]

# %%
# Print the first few rows of the transformed DataFrame
print("Transformed DataFrame:")
print(data.head())

# Save the transformed data to a CSV file
data.to_csv('transformed_data.csv')
# Out:
# Transformed DataFrame:
#                Value     lag_1     lag_2     lag_3     lag_4  lag_5  lag_6  \
# Date
# 2022-01-01  0.496714       NaN       NaN       NaN       NaN    NaN    NaN
# 2022-01-02 -0.138264  0.496714       NaN       NaN       NaN    NaN    NaN
# 2022-01-03  0.647689 -0.138264  0.496714       NaN       NaN    NaN    NaN
# 2022-01-04  1.523030  0.647689 -0.138264  0.496714       NaN    NaN    NaN
# 2022-01-05 -0.234153  1.523030  0.647689 -0.138264  0.496714    NaN    NaN
#
#             lag_7  rolling_mean  rolling_std  ...  day_of_week  month  \
# Date                                          ...
# 2022-01-01    NaN           NaN          NaN  ...            5      1
# 2022-01-02    NaN           NaN          NaN  ...            6      1
# 2022-01-03    NaN           NaN          NaN  ...            0      1
# 2022-01-04    NaN           NaN          NaN  ...            1      1
# 2022-01-05    NaN           NaN          NaN  ...            2      1
#
#             quarter  fourier_1  fourier_2  fourier_3  fourier_4  fourier_5  \
# Date
# 2022-01-01        1   0.024325   0.048642   0.072945   0.097227   0.121479
# 2022-01-02        1   0.048636   0.097214   0.145677   0.193968   0.242029
# 2022-01-03        1   0.072933   0.145671   0.218022   0.289792   0.360790
# 2022-01-04        1   0.097208   0.193956   0.289785   0.384244   0.476884
# 2022-01-05        1   0.121454   0.242011   0.360778   0.476878   0.589452
#
#             days_since_start  days_until_end_of_year
# Date
# 2022-01-01                 0                     364
# 2022-01-02                 1                     363
# 2022-01-03                 2                     362
# 2022-01-04                 3                     361
# 2022-01-05                 4                     360
#
# [5 rows x 22 columns]
